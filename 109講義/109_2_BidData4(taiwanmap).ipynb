# %%
#下載地理資訊連結
# !pip install geopandas

# %%
import geopandas as gpd
# import shapely
import pandas as pd
import matplotlib.pyplot as plt
# from matplotlib import patches as mpatches
plt.rcParams['figure.figsize']=(10,10)

# %%
#讀取台灣城鎮資訊及讀取中文字型(utf-8)
town_TA = gpd.read_file('TOWN_MOI_1081121.shp', encoding='utf-8')

# %%
town_TA
# Out:
#     TOWNID  ...                                           geometry
# 0      V02  ...  POLYGON ((121.40982 23.21369, 121.40984 23.213...
# 1      T21  ...  POLYGON ((120.54846 22.46067, 120.54853 22.460...
# 2      P13  ...  POLYGON ((120.30198 23.81625, 120.30197 23.815...
# 3      V11  ...  MULTIPOLYGON (((121.49155 22.67746, 121.49185 ...
# 4      V16  ...  MULTIPOLYGON (((121.61180 21.94290, 121.61133 ...
# ..     ...  ...                                                ...
# 363    D22  ...  POLYGON ((120.13989 23.19585, 120.14003 23.195...
# 364    D23  ...  POLYGON ((120.08374 23.24056, 120.08470 23.239...
# 365    H10  ...  POLYGON ((121.22256 24.94984, 121.22259 24.949...
# 366    E02  ...  POLYGON ((120.27878 22.67380, 120.27891 22.673...
# 367    E03  ...  POLYGON ((120.30865 22.65505, 120.30882 22.656...
#
# [368 rows x 8 columns]

# %%
#設定經緯度，繪出台灣地圖
x=town_TA.plot(column='COUNTYNAME',cmap='Blues')
x.set_xlim(119.7, 122.3) 
x.set_ylim(21.8, 25.4)
plt.title("Taiwan map",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Taiwan map')

# %%
#以COUNTYNAME指定為臺南市、繪製臺南地圖，RdBu：紅藍色
tainan_town1=town_TA[town_TA['COUNTYNAME']=='臺南市']
tainan_town1.plot(cmap="RdBu")

# %%
#載入各縣市染疫人數
data=pd.read_csv('exam1.csv')

# %%
#將各縣市染疫人數合併至台灣地圖資料，以城市名為合併依據(檔一:城市名變數:COUNTYNAME、檔二:城市名變數:AA)
town_A_no = town_TA.merge(data, left_on=('COUNTYNAME'), right_on=('AA'))

# %%
data
# Out:
#      AA  NO
# 0   基隆市   3
# 1   臺北市  84
# 2   新北市  72
# 3   桃園市  33
# 4   新竹市   7
# 5   新竹縣   4
# 6   苗栗縣   3
# 7   臺中市  33
# 8   彰化縣  14
# 9   南投縣   2
# 10  雲林縣   4
# 11  嘉義市   3
# 12  嘉義縣   3
# 13  臺南市  13
# 14  高雄市  25
# 15  屏東縣   6
# 16  臺東縣   0
# 17  花蓮縣   0
# 18  宜蘭縣   2
# 19  澎湖縣   0
# 20  金門縣   0
# 21  連江縣   0

# %%
town_A_no.head()
# Out:
#   TOWNID  TOWNCODE  ...   AA NO
# 0    V02  10014020  ...  臺東縣  0
# 1    V11  10014110  ...  臺東縣  0
# 2    V16  10014160  ...  臺東縣  0
# 3    V09  10014050  ...  臺東縣  0
# 4    V10  10014060  ...  臺東縣  0
#
# [5 rows x 10 columns]

# %%
#地圖顏色依確診數NO來繪圖
SA=town_A_no.plot(column='NO',cmap='Reds')
SA.set_xlim(119.5, 122.5)
SA.set_ylim(21.5, 25.5)
plt.title("The no. of COVID 2019 in Taiwan",fontsize=20)
# Out:
# Text(0.5, 1.0, 'The no. of COVID 2019 in Taiwan')

# %% [markdown]
# #Exercise: 請畫出幸福指數視覺化臺灣地圖圖形(請以2019縣市幸福指數資料繪圖：檔案exercise.xlsx, https://money.udn.com/ACT/2019/happy/index.html)

# %% [markdown]
# # 作業四：請畫出某日台灣天氣溫度的視覺化台灣地圖或某縣市地圖。
#
# (註：學號最後一個數字為1, 畫出4/1天氣溫度;學號最後一個數字為2, 畫出4/2天氣溫度;...依此類推)
#
# # 加分題：請自設視覺畫熱圖主題，畫出此主題的視覺化台灣地圖或某區域地圖。

# %%
import geopandas as gpd
# import shapely
import pandas as pd
import matplotlib.pyplot as plt
# from matplotlib import patches as mpatches
plt.rcParams['figure.figsize']=(10,10)
town_TA = gpd.read_file('TOWN_MOI_1081121.shp', encoding='utf-8')
df=pd.read_excel('exercise.xlsx')
town_A_no = town_TA.merge(df, left_on=('COUNTYNAME'), right_on=('AA'))

# %%
SA=town_A_no.plot(column='NO',cmap='PiYG')
SA.set_xlim(119.5, 122.5)
SA.set_ylim(21.5, 25.5)
plt.title("Happy level",fontsize=20)
plt.legend(labels=town_A_no['COUNTYID'])

# %%
sns.heatmap(df.)

# %%
town_A_no.drop_duplicates(subset=['COUNTYID'],keep='first').sort_values(by='COUNTYID')

# %%
town_A_no.groupby('COUNTYID')
